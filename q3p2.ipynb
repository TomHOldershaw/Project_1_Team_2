# %%
import pandas as pd

# %%
csv_path = "Resources/summer.csv"

# %%
amjad_df=pd.read_csv(csv_path)

# %%
amjad_df
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# ...

# %%
host_df=amjad_df.groupby('City')["Year"].unique()
host_df
# Out:
# City
# Amsterdam                            [1928]
# Antwerp                              [1920]
# Athens                         [1896, 2004]
# Atlanta                              [1996]
# Barcelona                            [1992]
# Beijing                              [2008]
# Berlin                               [1936]
# Helsinki                             [1952]
# London                   [1908, 1948, 2012]
# Los Angeles                    [1932, 1984]
# Melbourne / Stockholm                [1956]
# Mexico                               [1968]
# Montreal                             [1976]
# Moscow                               [1980]
# Munich                               [1972]
# Paris                          [1900, 1924]
# Rome                                 [1960]
# Seoul                                [1988]
# St Louis                             [1904]
# Stockholm                            [1912]
# Sydney                               [2000]
# ...

# %%
gbr_df=amjad_df.loc[(amjad_df["Country"] == "GBR") & ( (amjad_df["Year"] == 1896) | (amjad_df["Year"] == 1900) | (amjad_df["Year"] == 1904) )]
gbr_df
# Out:
#      Year      City      Sport     Discipline                   Athlete  \
# 16   1896    Athens  Athletics      Athletics        GOULDING, Grantley
# 20   1896    Athens  Athletics      Athletics           GMELIN, Charles
# 48   1896    Athens    Cycling   Cycling Road            BATTEL, Edward
# 57   1896    Athens    Cycling  Cycling Track            KEEPING, Frank
# 140  1896    Athens     Tennis         Tennis              BOLAND, John
# ..    ...       ...        ...            ...                       ...
# 645  1900     Paris     Tennis         Tennis    DOHERTY, Hugh Lawrence
# 646  1900     Paris     Tennis         Tennis  MAHONY, Harold Sergerson
# 649  1900     Paris     Tennis         Tennis         COOPER, Charlotte
# 753  1904  St Louis  Athletics      Athletics                DALY, John
# 780  1904  St Louis  Athletics      Athletics     KIELY, Thomas Francis
#
#     Country Gender                 Event   Medal
# 16      GBR    Men          110M Hurdles  Silver
# ...

# %%
athens_df=amjad_df.loc[(amjad_df["Country"] == "GRE") & ( (amjad_df["Year"] == 1896) | (amjad_df["Year"] == 1900) | (amjad_df["Year"] == 1904) )]
athens_df.head()
# Out:
#    Year    City     Sport Discipline                Athlete Country Gender  \
# 2  1896  Athens  Aquatics   Swimming      DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming     MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming     CHASAPIS, Spiridon     GRE    Men
# 5  1896  Athens  Aquatics   Swimming  CHOROPHAS, Efstathios     GRE    Men
# 7  1896  Athens  Aquatics   Swimming       ANDREOU, Joannis     GRE    Men
#
#                         Event   Medal
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver
# 5             1200M Freestyle  Bronze
# 7             1200M Freestyle  Silver

# %%
medal_df=pd.DataFrame(amjad_df.groupby(['City','Country','Year'])['Medal'].value_counts())
medal_df.sort_values(by=["Year"],ascending=False, ignore_index=False)
medal_df.head(60)
# Out:
#                                Medal
# City      Country Year Medal
# Amsterdam ARG     1928 Silver     24
#                        Bronze      5
#                        Gold        3
#           AUS     1928 Silver      2
#                        Bronze      1
#                        Gold        1
#           AUT     1928 Bronze      2
#                        Gold        2
#           BEL     1928 Bronze      4
#                        Silver      1
#           CAN     1928 Bronze     21
#                        Gold        7
#                        Silver      5
#           CHI     1928 Silver      1
#           DEN     1928 Gold        5
#                        Silver      5
#                        Bronze      3
#           EGY     1928 Gold        2
#                        Bronze      1
#                        Silver      1
#           ESP     1928 Gold        3
#           EST     1928 Bronze      6
#                        Gold        2
# ...

# %%
yearly_df=pd.DataFrame(amjad_df.groupby(['Country','Year'])['Medal'].value_counts().reset_index())
yearly_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-48a0cc4ed60e> in <module>
# ----> 1 yearly_df=pd.DataFrame(amjad_df.groupby(['Country','Year'])['Medal'].value_counts().reset_index())
#       2 yearly_df
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in reset_index(self, level, drop, name, inplace)
#    1276         else:
#    1277             df = self.to_frame(name)
# -> 1278             return df.reset_index(level=level, drop=drop)
#    1279
#    1280     # ----------------------------------------------------------------------
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    5014                 # to ndarray and maybe infer different dtype
#    5015                 level_values = maybe_casted_values(lev, lab)
# -> 5016                 new_obj.insert(0, name, level_values)
# ...

# %%
#athens_df=year_df.loc[(year_df["Country"] == "GRE") & ( (year_df["Year"] == 1896) | (year_df["Year"] == 1900) | (year_df["Year"] == 1904) )]
